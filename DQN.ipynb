# %% [markdown]
# In this notebook, we wil try to implement the DQN algorithm on **atari**. This will be using the **gym** library that allow us to better manage the environment.To implement this algorithm we need to define some classes that help to better save the transitions and the training of the algorithm.

# %%
# we import the necessary packages for our algorithm
import gym
import collections
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# From this class, we try to save the transitions in the environment with all the actions and the successive states inside the environment. This class contains three methods: put, sample and size.
# The **put** method allow us to append the last transition made in the environment and supervize the memory size, so that we use just the 50.000 last transitions to make the learning process.The **sample** method is used to sample a batch_size transitions in the environment and return the environment characteristics (actions, states and rewards) as tensor type. The **size** method return the size of the memory.

# %%
class Replay():
    def __init__(self):
        self.Replay = collections.deque()
        self.batch_size = 32
        self.size_limit = 50000
    
    def put(self, transition):
        self.Replay.append(transition)
        if len(self.Replay) > self.size_limit:
            self.Replay.popleft() # we let just the size limit transitions
    
    def sample(self, n):
        mini_batch = random.sample(self.Replay, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
        
    def size(self):
        return len(self.Replay)

# %% [markdown]
# In this part, we implement model used for the learning.Here, we implement a neural network with 3 linear layers with a relu activation.

# %%
class Qnetwork(nn.Module):#our class Qnetwork heritate from nn.Module in pytorch
    def __init__(self):
        super(Qnetwork, self).__init__()
        self.fc1 = nn.Linear(4, 64) # we start by building a Fully connected layer 
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 2) # fully connected layer: (right, left actions)
        
    def forward(self, x):
        x = F.relu(self.fc1(x)) #fully connected layer followed by a relu
        x = F.relu(self.fc2(x)) # fully connected layer followed by a relu
        x = self.fc3(x) # no relu since Q-value can be negative
        return x
    
    def sample_action(self, obs, epsilon): # epsilon-greedy 
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0,1)
        else:
            return out.argmax().item() # return the one with largest Q-val

# %%
# The funtion to train the model with a specified batch_size and optimizer
# we will use a RMSprop algorithm
def train(q, q_target, memory, gamma, optimizer, batch_size):
    for i in range(10):
        s,a,r,s_prime,done_mask = memory.sample(batch_size)
        
        q_out = q(s) # s.shape: 32,4 / q.shape: 32,2
        q_a = q_out.gather(1,a) # Extracting q values only for the actions taken (32,2 -> 32,1)
                                # because action includes q val for both direction: right and left
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r + gamma * max_q_prime * done_mask
        loss = F.smooth_l1_loss(target, q_a)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
def main():
    env = gym.make('CartPole-v1')
    q = Qnetwork()
    q_target = Qnetwork() # create instance
    q_target.load_state_dict(q.state_dict()) # duplicate
    memory = Replay()
    
    print_interval = 20
    score = 0.0
    render = False
    
    gamma = 0.98
    batch_size = 32
    optimizer = optim.RMSprop(q.parameters(), lr=0.0005)# we are using RMSProp as the article did 
    # we don't update Target Q's parameters
    
    for n_epi in range(10000):
        epsilon = max(0.01, 0.08 - 0.01*(n_epi/200))# epsilon decreases from 8% to 1% linearly throughout episodes
        s = env.reset()
        done = False
        if render:
            env.render()
        
        for t in range(600):
            a = q.sample_action(torch.from_numpy(s).float(), epsilon)
            s_prime, r, done, info = env.step(a)
            done_mask = 0.0 if done else 1.0 # will be multiplied to TD value later(?)
            memory.put((s,a,r/200.0, s_prime, done_mask))
            s = s_prime
            
            score += r
            if score > 1000:
                render = True
            if done:
                break
                
        if memory.size()>2000:# We only stack memories until 2000 and then start training
            train(q, q_target, memory, gamma, optimizer, batch_size)
            
            
        if n_epi%20==0 and n_epi!=0:
            q_target.load_state_dict(q.state_dict()) # update target Q every 20 episode
            print(f"Episode {n_epi}:  Buffer size: {memory.size()}, Score: {score}, EPS: {epsilon*100:.1f}")
            
            score = 0.0
    env.close()

if __name__ == '__main__':
    q_value = main()
# Out:
# Episode 20:  Buffer size: 666, Score: 666.0, EPS: 7.9
# Episode 40:  Buffer size: 1323, Score: 657.0, EPS: 7.8
# Episode 60:  Buffer size: 2000, Score: 677.0, EPS: 7.7
# C:\Users\acer\AppData\Local\Temp/ipykernel_18588/2591881847.py:24: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ..\torch\csrc\utils\tensor_new.cpp:201.)
#   return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
# Episode 80:  Buffer size: 2249, Score: 249.0, EPS: 7.6
# Episode 100:  Buffer size: 2452, Score: 203.0, EPS: 7.5
# Episode 120:  Buffer size: 2646, Score: 194.0, EPS: 7.4
# Episode 140:  Buffer size: 2839, Score: 193.0, EPS: 7.3
# Episode 160:  Buffer size: 3076, Score: 237.0, EPS: 7.2
# Episode 180:  Buffer size: 3372, Score: 296.0, EPS: 7.1
# Episode 200:  Buffer size: 3892, Score: 520.0, EPS: 7.0
# Episode 220:  Buffer size: 4773, Score: 881.0, EPS: 6.9
# Episode 240:  Buffer size: 6042, Score: 1269.0, EPS: 6.8
# Episode 260:  Buffer size: 6911, Score: 869.0, EPS: 6.7
# Episode 280:  Buffer size: 9369, Score: 2458.0, EPS: 6.6
# Episode 300:  Buffer size: 14481, Score: 5112.0, EPS: 6.5
# Episode 320:  Buffer size: 19947, Score: 5466.0, EPS: 6.4
# Episode 340:  Buffer size: 28031, Score: 8084.0, EPS: 6.3
# Episode 360:  Buffer size: 35632, Score: 7601.0, EPS: 6.2
# Episode 380:  Buffer size: 44753, Score: 9121.0, EPS: 6.1
# Episode 400:  Buffer size: 50000, Score: 8653.0, EPS: 6.0
# Episode 420:  Buffer size: 50000, Score: 8649.0, EPS: 5.9
# Episode 440:  Buffer size: 50000, Score: 8918.0, EPS: 5.8
# Episode 460:  Buffer size: 50000, Score: 8104.0, EPS: 5.7
# Episode 480:  Buffer size: 50000, Score: 9351.0, EPS: 5.6
# Episode 500:  Buffer size: 50000, Score: 9131.0, EPS: 5.5
# Episode 520:  Buffer size: 50000, Score: 5877.0, EPS: 5.4
# Episode 540:  Buffer size: 50000, Score: 7466.0, EPS: 5.3
# Episode 560:  Buffer size: 50000, Score: 7072.0, EPS: 5.2
# Episode 580:  Buffer size: 50000, Score: 6809.0, EPS: 5.1
# Episode 600:  Buffer size: 50000, Score: 7945.0, EPS: 5.0
# Episode 620:  Buffer size: 50000, Score: 6122.0, EPS: 4.9
# Episode 640:  Buffer size: 50000, Score: 6162.0, EPS: 4.8
# Episode 660:  Buffer size: 50000, Score: 5119.0, EPS: 4.7
# Episode 680:  Buffer size: 50000, Score: 3159.0, EPS: 4.6
# Episode 700:  Buffer size: 50000, Score: 6085.0, EPS: 4.5
# Episode 720:  Buffer size: 50000, Score: 3696.0, EPS: 4.4
# Episode 740:  Buffer size: 50000, Score: 3816.0, EPS: 4.3
# Episode 760:  Buffer size: 50000, Score: 5754.0, EPS: 4.2
# Episode 780:  Buffer size: 50000, Score: 4780.0, EPS: 4.1
# Episode 800:  Buffer size: 50000, Score: 7864.0, EPS: 4.0
# Episode 820:  Buffer size: 50000, Score: 6903.0, EPS: 3.9
# Episode 840:  Buffer size: 50000, Score: 5361.0, EPS: 3.8
# Episode 860:  Buffer size: 50000, Score: 9205.0, EPS: 3.7
# Episode 880:  Buffer size: 50000, Score: 7066.0, EPS: 3.6
# Episode 900:  Buffer size: 50000, Score: 4532.0, EPS: 3.5
# Episode 920:  Buffer size: 50000, Score: 3424.0, EPS: 3.4
# Episode 940:  Buffer size: 50000, Score: 3003.0, EPS: 3.3
# Episode 960:  Buffer size: 50000, Score: 4824.0, EPS: 3.2
# Episode 980:  Buffer size: 50000, Score: 5369.0, EPS: 3.1
# Episode 1000:  Buffer size: 50000, Score: 2756.0, EPS: 3.0
# Episode 1020:  Buffer size: 50000, Score: 1773.0, EPS: 2.9
# Episode 1040:  Buffer size: 50000, Score: 2662.0, EPS: 2.8
# Episode 1060:  Buffer size: 50000, Score: 4435.0, EPS: 2.7
# Episode 1080:  Buffer size: 50000, Score: 6862.0, EPS: 2.6
# Episode 1100:  Buffer size: 50000, Score: 4331.0, EPS: 2.5
# Episode 1120:  Buffer size: 50000, Score: 6586.0, EPS: 2.4
# Episode 1140:  Buffer size: 50000, Score: 5140.0, EPS: 2.3
# Episode 1160:  Buffer size: 50000, Score: 6623.0, EPS: 2.2
# Episode 1180:  Buffer size: 50000, Score: 7306.0, EPS: 2.1
# Episode 1200:  Buffer size: 50000, Score: 5572.0, EPS: 2.0
# Episode 1220:  Buffer size: 50000, Score: 5389.0, EPS: 1.9
# Episode 1240:  Buffer size: 50000, Score: 2776.0, EPS: 1.8
# Episode 1260:  Buffer size: 50000, Score: 2273.0, EPS: 1.7
# Episode 1280:  Buffer size: 50000, Score: 5003.0, EPS: 1.6
# Episode 1300:  Buffer size: 50000, Score: 3818.0, EPS: 1.5
# Episode 1320:  Buffer size: 50000, Score: 3843.0, EPS: 1.4
# Episode 1340:  Buffer size: 50000, Score: 2109.0, EPS: 1.3
# Episode 1360:  Buffer size: 50000, Score: 5032.0, EPS: 1.2
# Episode 1380:  Buffer size: 50000, Score: 6457.0, EPS: 1.1
# Episode 1400:  Buffer size: 50000, Score: 7158.0, EPS: 1.0
# Episode 1420:  Buffer size: 50000, Score: 6923.0, EPS: 1.0
# Episode 1440:  Buffer size: 50000, Score: 6151.0, EPS: 1.0
# Episode 1460:  Buffer size: 50000, Score: 8563.0, EPS: 1.0
# Episode 1480:  Buffer size: 50000, Score: 1777.0, EPS: 1.0
# Episode 1500:  Buffer size: 50000, Score: 6384.0, EPS: 1.0
# Episode 1520:  Buffer size: 50000, Score: 5971.0, EPS: 1.0
# Episode 1540:  Buffer size: 50000, Score: 6510.0, EPS: 1.0
# Episode 1560:  Buffer size: 50000, Score: 5465.0, EPS: 1.0
# Episode 1580:  Buffer size: 50000, Score: 7912.0, EPS: 1.0
# Episode 1600:  Buffer size: 50000, Score: 5152.0, EPS: 1.0
# Episode 1620:  Buffer size: 50000, Score: 8663.0, EPS: 1.0
# Episode 1640:  Buffer size: 50000, Score: 7622.0, EPS: 1.0
# Episode 1660:  Buffer size: 50000, Score: 7050.0, EPS: 1.0
# Episode 1680:  Buffer size: 50000, Score: 9712.0, EPS: 1.0
# Episode 1700:  Buffer size: 50000, Score: 6412.0, EPS: 1.0
# Episode 1720:  Buffer size: 50000, Score: 2730.0, EPS: 1.0
# Episode 1740:  Buffer size: 50000, Score: 2882.0, EPS: 1.0
# Episode 1760:  Buffer size: 50000, Score: 6280.0, EPS: 1.0
# Episode 1780:  Buffer size: 50000, Score: 6179.0, EPS: 1.0
# Episode 1800:  Buffer size: 50000, Score: 7291.0, EPS: 1.0
# Episode 1820:  Buffer size: 50000, Score: 6683.0, EPS: 1.0
# Episode 1840:  Buffer size: 50000, Score: 3707.0, EPS: 1.0
# Episode 1860:  Buffer size: 50000, Score: 7964.0, EPS: 1.0
# Episode 1880:  Buffer size: 50000, Score: 3490.0, EPS: 1.0
# Episode 1900:  Buffer size: 50000, Score: 3825.0, EPS: 1.0
# Episode 1920:  Buffer size: 50000, Score: 3556.0, EPS: 1.0
# Episode 1940:  Buffer size: 50000, Score: 7586.0, EPS: 1.0
# Episode 1960:  Buffer size: 50000, Score: 5854.0, EPS: 1.0
# Episode 1980:  Buffer size: 50000, Score: 6899.0, EPS: 1.0
# Episode 2000:  Buffer size: 50000, Score: 5558.0, EPS: 1.0
# Episode 2020:  Buffer size: 50000, Score: 8204.0, EPS: 1.0
# Episode 2040:  Buffer size: 50000, Score: 7473.0, EPS: 1.0
# Episode 2060:  Buffer size: 50000, Score: 8299.0, EPS: 1.0
# Episode 2080:  Buffer size: 50000, Score: 8417.0, EPS: 1.0
# Episode 2100:  Buffer size: 50000, Score: 5805.0, EPS: 1.0
# Episode 2120:  Buffer size: 50000, Score: 6729.0, EPS: 1.0
# Episode 2140:  Buffer size: 50000, Score: 7636.0, EPS: 1.0
# Episode 2160:  Buffer size: 50000, Score: 5850.0, EPS: 1.0
# Episode 2180:  Buffer size: 50000, Score: 6403.0, EPS: 1.0
# Episode 2200:  Buffer size: 50000, Score: 5928.0, EPS: 1.0
# Episode 2220:  Buffer size: 50000, Score: 5393.0, EPS: 1.0
# Episode 2240:  Buffer size: 50000, Score: 5931.0, EPS: 1.0
# Episode 2260:  Buffer size: 50000, Score: 4934.0, EPS: 1.0
# Episode 2280:  Buffer size: 50000, Score: 4824.0, EPS: 1.0
# Episode 2300:  Buffer size: 50000, Score: 6526.0, EPS: 1.0
# Episode 2320:  Buffer size: 50000, Score: 8030.0, EPS: 1.0
# Episode 2340:  Buffer size: 50000, Score: 6369.0, EPS: 1.0
# Episode 2360:  Buffer size: 50000, Score: 8961.0, EPS: 1.0
# Episode 2380:  Buffer size: 50000, Score: 8536.0, EPS: 1.0
# Episode 2400:  Buffer size: 50000, Score: 8026.0, EPS: 1.0
# Episode 2420:  Buffer size: 50000, Score: 7407.0, EPS: 1.0
# Episode 2440:  Buffer size: 50000, Score: 7502.0, EPS: 1.0
# Episode 2460:  Buffer size: 50000, Score: 9146.0, EPS: 1.0
# Episode 2480:  Buffer size: 50000, Score: 4233.0, EPS: 1.0
# Episode 2500:  Buffer size: 50000, Score: 3612.0, EPS: 1.0
# Episode 2520:  Buffer size: 50000, Score: 6031.0, EPS: 1.0
# Episode 2540:  Buffer size: 50000, Score: 9517.0, EPS: 1.0
# Episode 2560:  Buffer size: 50000, Score: 7561.0, EPS: 1.0
# Episode 2580:  Buffer size: 50000, Score: 8983.0, EPS: 1.0
# Episode 2600:  Buffer size: 50000, Score: 9530.0, EPS: 1.0
# Episode 2620:  Buffer size: 50000, Score: 8765.0, EPS: 1.0
# Episode 2640:  Buffer size: 50000, Score: 8174.0, EPS: 1.0
# Episode 2660:  Buffer size: 50000, Score: 8878.0, EPS: 1.0
# Episode 2680:  Buffer size: 50000, Score: 6264.0, EPS: 1.0
# Episode 2700:  Buffer size: 50000, Score: 6286.0, EPS: 1.0
# Episode 2720:  Buffer size: 50000, Score: 9032.0, EPS: 1.0
# Episode 2740:  Buffer size: 50000, Score: 7637.0, EPS: 1.0
# Episode 2760:  Buffer size: 50000, Score: 8115.0, EPS: 1.0
# Episode 2780:  Buffer size: 50000, Score: 7941.0, EPS: 1.0
# Episode 2800:  Buffer size: 50000, Score: 8961.0, EPS: 1.0
# Episode 2820:  Buffer size: 50000, Score: 8517.0, EPS: 1.0
# Episode 2840:  Buffer size: 50000, Score: 7595.0, EPS: 1.0
# Episode 2860:  Buffer size: 50000, Score: 8030.0, EPS: 1.0
# Episode 2880:  Buffer size: 50000, Score: 8708.0, EPS: 1.0
# Episode 2900:  Buffer size: 50000, Score: 7621.0, EPS: 1.0
# Episode 2920:  Buffer size: 50000, Score: 9531.0, EPS: 1.0
# Episode 2940:  Buffer size: 50000, Score: 7329.0, EPS: 1.0
# Episode 2960:  Buffer size: 50000, Score: 6117.0, EPS: 1.0
# Episode 2980:  Buffer size: 50000, Score: 5719.0, EPS: 1.0
# Episode 3000:  Buffer size: 50000, Score: 4472.0, EPS: 1.0
# Episode 3020:  Buffer size: 50000, Score: 5000.0, EPS: 1.0
# Episode 3040:  Buffer size: 50000, Score: 6011.0, EPS: 1.0
# Episode 3060:  Buffer size: 50000, Score: 7900.0, EPS: 1.0
# Episode 3080:  Buffer size: 50000, Score: 6522.0, EPS: 1.0
# Episode 3100:  Buffer size: 50000, Score: 7172.0, EPS: 1.0
# Episode 3120:  Buffer size: 50000, Score: 6954.0, EPS: 1.0
# Episode 3140:  Buffer size: 50000, Score: 4429.0, EPS: 1.0
# Episode 3160:  Buffer size: 50000, Score: 6902.0, EPS: 1.0
# Episode 3180:  Buffer size: 50000, Score: 8721.0, EPS: 1.0
# Episode 3200:  Buffer size: 50000, Score: 8738.0, EPS: 1.0
# Episode 3220:  Buffer size: 50000, Score: 8811.0, EPS: 1.0
# Episode 3240:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 3260:  Buffer size: 50000, Score: 9682.0, EPS: 1.0
# Episode 3280:  Buffer size: 50000, Score: 8582.0, EPS: 1.0
# Episode 3300:  Buffer size: 50000, Score: 9518.0, EPS: 1.0
# Episode 3320:  Buffer size: 50000, Score: 9652.0, EPS: 1.0
# Episode 3340:  Buffer size: 50000, Score: 9491.0, EPS: 1.0
# Episode 3360:  Buffer size: 50000, Score: 9039.0, EPS: 1.0
# Episode 3380:  Buffer size: 50000, Score: 8650.0, EPS: 1.0
# Episode 3400:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 3420:  Buffer size: 50000, Score: 9167.0, EPS: 1.0
# Episode 3440:  Buffer size: 50000, Score: 9033.0, EPS: 1.0
# Episode 3460:  Buffer size: 50000, Score: 3605.0, EPS: 1.0
# Episode 3480:  Buffer size: 50000, Score: 3362.0, EPS: 1.0
# Episode 3500:  Buffer size: 50000, Score: 8451.0, EPS: 1.0
# Episode 3520:  Buffer size: 50000, Score: 9063.0, EPS: 1.0
# Episode 3540:  Buffer size: 50000, Score: 8914.0, EPS: 1.0
# Episode 3560:  Buffer size: 50000, Score: 9612.0, EPS: 1.0
# Episode 3580:  Buffer size: 50000, Score: 8645.0, EPS: 1.0
# Episode 3600:  Buffer size: 50000, Score: 9491.0, EPS: 1.0
# Episode 3620:  Buffer size: 50000, Score: 6619.0, EPS: 1.0
# Episode 3640:  Buffer size: 50000, Score: 4863.0, EPS: 1.0
# Episode 3660:  Buffer size: 50000, Score: 8923.0, EPS: 1.0
# Episode 3680:  Buffer size: 50000, Score: 9302.0, EPS: 1.0
# Episode 3700:  Buffer size: 50000, Score: 9050.0, EPS: 1.0
# Episode 3720:  Buffer size: 50000, Score: 9490.0, EPS: 1.0
# Episode 3740:  Buffer size: 50000, Score: 7451.0, EPS: 1.0
# Episode 3760:  Buffer size: 50000, Score: 8903.0, EPS: 1.0
# Episode 3780:  Buffer size: 50000, Score: 7512.0, EPS: 1.0
# Episode 3800:  Buffer size: 50000, Score: 8751.0, EPS: 1.0
# Episode 3820:  Buffer size: 50000, Score: 8221.0, EPS: 1.0
# Episode 3840:  Buffer size: 50000, Score: 3701.0, EPS: 1.0
# Episode 3860:  Buffer size: 50000, Score: 3725.0, EPS: 1.0
# Episode 3880:  Buffer size: 50000, Score: 2493.0, EPS: 1.0
# Episode 3900:  Buffer size: 50000, Score: 2722.0, EPS: 1.0
# Episode 3920:  Buffer size: 50000, Score: 1701.0, EPS: 1.0
# Episode 3940:  Buffer size: 50000, Score: 8284.0, EPS: 1.0
# Episode 3960:  Buffer size: 50000, Score: 8702.0, EPS: 1.0
# Episode 3980:  Buffer size: 50000, Score: 9567.0, EPS: 1.0
# Episode 4000:  Buffer size: 50000, Score: 9483.0, EPS: 1.0
# Episode 4020:  Buffer size: 50000, Score: 9259.0, EPS: 1.0
# Episode 4040:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 4060:  Buffer size: 50000, Score: 7201.0, EPS: 1.0
# Episode 4080:  Buffer size: 50000, Score: 8952.0, EPS: 1.0
# Episode 4100:  Buffer size: 50000, Score: 8074.0, EPS: 1.0
# Episode 4120:  Buffer size: 50000, Score: 9180.0, EPS: 1.0
# Episode 4140:  Buffer size: 50000, Score: 8999.0, EPS: 1.0
# Episode 4160:  Buffer size: 50000, Score: 4494.0, EPS: 1.0
# Episode 4180:  Buffer size: 50000, Score: 8245.0, EPS: 1.0
# Episode 4200:  Buffer size: 50000, Score: 8894.0, EPS: 1.0
# Episode 4220:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 4240:  Buffer size: 50000, Score: 9613.0, EPS: 1.0
# Episode 4260:  Buffer size: 50000, Score: 9520.0, EPS: 1.0
# Episode 4280:  Buffer size: 50000, Score: 9384.0, EPS: 1.0
# Episode 4300:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 4320:  Buffer size: 50000, Score: 8552.0, EPS: 1.0
# Episode 4340:  Buffer size: 50000, Score: 9289.0, EPS: 1.0
# Episode 4360:  Buffer size: 50000, Score: 9028.0, EPS: 1.0
# Episode 4380:  Buffer size: 50000, Score: 8546.0, EPS: 1.0
# Episode 4400:  Buffer size: 50000, Score: 9519.0, EPS: 1.0
# Episode 4420:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 4440:  Buffer size: 50000, Score: 8546.0, EPS: 1.0
# Episode 4460:  Buffer size: 50000, Score: 9964.0, EPS: 1.0
# Episode 4480:  Buffer size: 50000, Score: 9239.0, EPS: 1.0
# Episode 4500:  Buffer size: 50000, Score: 8976.0, EPS: 1.0
# Episode 4520:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 4540:  Buffer size: 50000, Score: 5920.0, EPS: 1.0
# Episode 4560:  Buffer size: 50000, Score: 7669.0, EPS: 1.0
# Episode 4580:  Buffer size: 50000, Score: 6147.0, EPS: 1.0
# Episode 4600:  Buffer size: 50000, Score: 4285.0, EPS: 1.0
# Episode 4620:  Buffer size: 50000, Score: 4465.0, EPS: 1.0
# Episode 4640:  Buffer size: 50000, Score: 5247.0, EPS: 1.0
# Episode 4660:  Buffer size: 50000, Score: 7395.0, EPS: 1.0
# Episode 4680:  Buffer size: 50000, Score: 8857.0, EPS: 1.0
# Episode 4700:  Buffer size: 50000, Score: 6431.0, EPS: 1.0
# Episode 4720:  Buffer size: 50000, Score: 6052.0, EPS: 1.0
# Episode 4740:  Buffer size: 50000, Score: 6526.0, EPS: 1.0
# Episode 4760:  Buffer size: 50000, Score: 6212.0, EPS: 1.0
# Episode 4780:  Buffer size: 50000, Score: 9340.0, EPS: 1.0
# Episode 4800:  Buffer size: 50000, Score: 4803.0, EPS: 1.0
# Episode 4820:  Buffer size: 50000, Score: 7139.0, EPS: 1.0
# Episode 4840:  Buffer size: 50000, Score: 9209.0, EPS: 1.0
# Episode 4860:  Buffer size: 50000, Score: 8891.0, EPS: 1.0
# Episode 4880:  Buffer size: 50000, Score: 8518.0, EPS: 1.0
# Episode 4900:  Buffer size: 50000, Score: 7661.0, EPS: 1.0
# Episode 4920:  Buffer size: 50000, Score: 9175.0, EPS: 1.0
# Episode 4940:  Buffer size: 50000, Score: 9047.0, EPS: 1.0
# Episode 4960:  Buffer size: 50000, Score: 8866.0, EPS: 1.0
# Episode 4980:  Buffer size: 50000, Score: 9518.0, EPS: 1.0
# Episode 5000:  Buffer size: 50000, Score: 8342.0, EPS: 1.0
# Episode 5020:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 5040:  Buffer size: 50000, Score: 8927.0, EPS: 1.0
# Episode 5060:  Buffer size: 50000, Score: 8314.0, EPS: 1.0
# Episode 5080:  Buffer size: 50000, Score: 8468.0, EPS: 1.0
# Episode 5100:  Buffer size: 50000, Score: 8642.0, EPS: 1.0
# Episode 5120:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 5140:  Buffer size: 50000, Score: 9677.0, EPS: 1.0
# Episode 5160:  Buffer size: 50000, Score: 9074.0, EPS: 1.0
# Episode 5180:  Buffer size: 50000, Score: 9840.0, EPS: 1.0
# Episode 5200:  Buffer size: 50000, Score: 5637.0, EPS: 1.0
# Episode 5220:  Buffer size: 50000, Score: 7388.0, EPS: 1.0
# Episode 5240:  Buffer size: 50000, Score: 9676.0, EPS: 1.0
# Episode 5260:  Buffer size: 50000, Score: 8676.0, EPS: 1.0
# Episode 5280:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 5300:  Buffer size: 50000, Score: 9051.0, EPS: 1.0
# Episode 5320:  Buffer size: 50000, Score: 8971.0, EPS: 1.0
# Episode 5340:  Buffer size: 50000, Score: 9721.0, EPS: 1.0
# Episode 5360:  Buffer size: 50000, Score: 8901.0, EPS: 1.0
# Episode 5380:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 5400:  Buffer size: 50000, Score: 9159.0, EPS: 1.0
# Episode 5420:  Buffer size: 50000, Score: 9202.0, EPS: 1.0
# Episode 5440:  Buffer size: 50000, Score: 9773.0, EPS: 1.0
# Episode 5460:  Buffer size: 50000, Score: 9195.0, EPS: 1.0
# Episode 5480:  Buffer size: 50000, Score: 9598.0, EPS: 1.0
# Episode 5500:  Buffer size: 50000, Score: 9670.0, EPS: 1.0
# Episode 5520:  Buffer size: 50000, Score: 9484.0, EPS: 1.0
# Episode 5540:  Buffer size: 50000, Score: 8425.0, EPS: 1.0
# Episode 5560:  Buffer size: 50000, Score: 9516.0, EPS: 1.0
# Episode 5580:  Buffer size: 50000, Score: 9109.0, EPS: 1.0
# Episode 5600:  Buffer size: 50000, Score: 8231.0, EPS: 1.0
# Episode 5620:  Buffer size: 50000, Score: 9804.0, EPS: 1.0
# Episode 5640:  Buffer size: 50000, Score: 6949.0, EPS: 1.0
# Episode 5660:  Buffer size: 50000, Score: 7386.0, EPS: 1.0
# Episode 5680:  Buffer size: 50000, Score: 8999.0, EPS: 1.0
# Episode 5700:  Buffer size: 50000, Score: 8588.0, EPS: 1.0
# Episode 5720:  Buffer size: 50000, Score: 8696.0, EPS: 1.0
# Episode 5740:  Buffer size: 50000, Score: 9113.0, EPS: 1.0
# Episode 5760:  Buffer size: 50000, Score: 7387.0, EPS: 1.0
# Episode 5780:  Buffer size: 50000, Score: 3777.0, EPS: 1.0
# Episode 5800:  Buffer size: 50000, Score: 2645.0, EPS: 1.0
# Episode 5820:  Buffer size: 50000, Score: 4062.0, EPS: 1.0
# Episode 5840:  Buffer size: 50000, Score: 3311.0, EPS: 1.0
# Episode 5860:  Buffer size: 50000, Score: 3137.0, EPS: 1.0
# Episode 5880:  Buffer size: 50000, Score: 3208.0, EPS: 1.0
# Episode 5900:  Buffer size: 50000, Score: 5275.0, EPS: 1.0
# Episode 5920:  Buffer size: 50000, Score: 4909.0, EPS: 1.0
# Episode 5940:  Buffer size: 50000, Score: 2838.0, EPS: 1.0
# Episode 5960:  Buffer size: 50000, Score: 3633.0, EPS: 1.0
# Episode 5980:  Buffer size: 50000, Score: 4147.0, EPS: 1.0
# Episode 6000:  Buffer size: 50000, Score: 2363.0, EPS: 1.0
# Episode 6020:  Buffer size: 50000, Score: 6590.0, EPS: 1.0
# Episode 6040:  Buffer size: 50000, Score: 7059.0, EPS: 1.0
# Episode 6060:  Buffer size: 50000, Score: 5882.0, EPS: 1.0
# Episode 6080:  Buffer size: 50000, Score: 9115.0, EPS: 1.0
# Episode 6100:  Buffer size: 50000, Score: 2820.0, EPS: 1.0
# Episode 6120:  Buffer size: 50000, Score: 3181.0, EPS: 1.0
# Episode 6140:  Buffer size: 50000, Score: 2972.0, EPS: 1.0
# Episode 6160:  Buffer size: 50000, Score: 3497.0, EPS: 1.0
# Episode 6180:  Buffer size: 50000, Score: 5334.0, EPS: 1.0
# Episode 6200:  Buffer size: 50000, Score: 4383.0, EPS: 1.0
# Episode 6220:  Buffer size: 50000, Score: 3818.0, EPS: 1.0
# Episode 6240:  Buffer size: 50000, Score: 4144.0, EPS: 1.0
# Episode 6260:  Buffer size: 50000, Score: 2791.0, EPS: 1.0
# Episode 6280:  Buffer size: 50000, Score: 2719.0, EPS: 1.0
# Episode 6300:  Buffer size: 50000, Score: 1418.0, EPS: 1.0
# Episode 6320:  Buffer size: 50000, Score: 3445.0, EPS: 1.0
# Episode 6340:  Buffer size: 50000, Score: 2369.0, EPS: 1.0
# Episode 6360:  Buffer size: 50000, Score: 5518.0, EPS: 1.0
# Episode 6380:  Buffer size: 50000, Score: 5355.0, EPS: 1.0
# Episode 6400:  Buffer size: 50000, Score: 3125.0, EPS: 1.0
# Episode 6420:  Buffer size: 50000, Score: 2273.0, EPS: 1.0
# Episode 6440:  Buffer size: 50000, Score: 2301.0, EPS: 1.0
# Episode 6460:  Buffer size: 50000, Score: 2330.0, EPS: 1.0
# Episode 6480:  Buffer size: 50000, Score: 2297.0, EPS: 1.0
# Episode 6500:  Buffer size: 50000, Score: 3600.0, EPS: 1.0
# Episode 6520:  Buffer size: 50000, Score: 3089.0, EPS: 1.0
# Episode 6540:  Buffer size: 50000, Score: 2549.0, EPS: 1.0
# Episode 6560:  Buffer size: 50000, Score: 2806.0, EPS: 1.0
# Episode 6580:  Buffer size: 50000, Score: 2572.0, EPS: 1.0
# Episode 6600:  Buffer size: 50000, Score: 2502.0, EPS: 1.0
# Episode 6620:  Buffer size: 50000, Score: 3016.0, EPS: 1.0
# Episode 6640:  Buffer size: 50000, Score: 2709.0, EPS: 1.0
# Episode 6660:  Buffer size: 50000, Score: 3663.0, EPS: 1.0
# Episode 6680:  Buffer size: 50000, Score: 3987.0, EPS: 1.0
# Episode 6700:  Buffer size: 50000, Score: 5507.0, EPS: 1.0
# Episode 6720:  Buffer size: 50000, Score: 3258.0, EPS: 1.0
# Episode 6740:  Buffer size: 50000, Score: 3457.0, EPS: 1.0
# Episode 6760:  Buffer size: 50000, Score: 4142.0, EPS: 1.0
# Episode 6780:  Buffer size: 50000, Score: 2840.0, EPS: 1.0
# Episode 6800:  Buffer size: 50000, Score: 3350.0, EPS: 1.0
# Episode 6820:  Buffer size: 50000, Score: 3765.0, EPS: 1.0
# Episode 6840:  Buffer size: 50000, Score: 3212.0, EPS: 1.0
# Episode 6860:  Buffer size: 50000, Score: 4023.0, EPS: 1.0
# Episode 6880:  Buffer size: 50000, Score: 3540.0, EPS: 1.0
# Episode 6900:  Buffer size: 50000, Score: 5472.0, EPS: 1.0
# Episode 6920:  Buffer size: 50000, Score: 4602.0, EPS: 1.0
# Episode 6940:  Buffer size: 50000, Score: 7279.0, EPS: 1.0
# Episode 6960:  Buffer size: 50000, Score: 6345.0, EPS: 1.0
# Episode 6980:  Buffer size: 50000, Score: 9334.0, EPS: 1.0
# Episode 7000:  Buffer size: 50000, Score: 8965.0, EPS: 1.0
# Episode 7020:  Buffer size: 50000, Score: 8996.0, EPS: 1.0
# Episode 7040:  Buffer size: 50000, Score: 9103.0, EPS: 1.0
# Episode 7060:  Buffer size: 50000, Score: 6648.0, EPS: 1.0
# Episode 7080:  Buffer size: 50000, Score: 8204.0, EPS: 1.0
# Episode 7100:  Buffer size: 50000, Score: 7944.0, EPS: 1.0
# Episode 7120:  Buffer size: 50000, Score: 9240.0, EPS: 1.0
# Episode 7140:  Buffer size: 50000, Score: 9539.0, EPS: 1.0
# Episode 7160:  Buffer size: 50000, Score: 9100.0, EPS: 1.0
# Episode 7180:  Buffer size: 50000, Score: 8171.0, EPS: 1.0
# Episode 7200:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 7220:  Buffer size: 50000, Score: 9446.0, EPS: 1.0
# Episode 7240:  Buffer size: 50000, Score: 8787.0, EPS: 1.0
# Episode 7260:  Buffer size: 50000, Score: 8283.0, EPS: 1.0
# Episode 7280:  Buffer size: 50000, Score: 9653.0, EPS: 1.0
# Episode 7300:  Buffer size: 50000, Score: 6566.0, EPS: 1.0
# Episode 7320:  Buffer size: 50000, Score: 8179.0, EPS: 1.0
# Episode 7340:  Buffer size: 50000, Score: 7849.0, EPS: 1.0
# Episode 7360:  Buffer size: 50000, Score: 6906.0, EPS: 1.0
# Episode 7380:  Buffer size: 50000, Score: 7166.0, EPS: 1.0
# Episode 7400:  Buffer size: 50000, Score: 7246.0, EPS: 1.0
# Episode 7420:  Buffer size: 50000, Score: 6219.0, EPS: 1.0
# Episode 7440:  Buffer size: 50000, Score: 9021.0, EPS: 1.0
# Episode 7460:  Buffer size: 50000, Score: 1612.0, EPS: 1.0
# Episode 7480:  Buffer size: 50000, Score: 5014.0, EPS: 1.0
# Episode 7500:  Buffer size: 50000, Score: 4555.0, EPS: 1.0
# Episode 7520:  Buffer size: 50000, Score: 4864.0, EPS: 1.0
# Episode 7540:  Buffer size: 50000, Score: 2942.0, EPS: 1.0
# Episode 7560:  Buffer size: 50000, Score: 2409.0, EPS: 1.0
# Episode 7580:  Buffer size: 50000, Score: 2911.0, EPS: 1.0
# Episode 7600:  Buffer size: 50000, Score: 2831.0, EPS: 1.0
# Episode 7620:  Buffer size: 50000, Score: 4592.0, EPS: 1.0
# Episode 7640:  Buffer size: 50000, Score: 1926.0, EPS: 1.0
# Episode 7660:  Buffer size: 50000, Score: 1491.0, EPS: 1.0
# Episode 7680:  Buffer size: 50000, Score: 2832.0, EPS: 1.0
# Episode 7700:  Buffer size: 50000, Score: 7644.0, EPS: 1.0
# Episode 7720:  Buffer size: 50000, Score: 8857.0, EPS: 1.0
# Episode 7740:  Buffer size: 50000, Score: 9631.0, EPS: 1.0
# Episode 7760:  Buffer size: 50000, Score: 9335.0, EPS: 1.0
# Episode 7780:  Buffer size: 50000, Score: 6137.0, EPS: 1.0
# Episode 7800:  Buffer size: 50000, Score: 7055.0, EPS: 1.0
# Episode 7820:  Buffer size: 50000, Score: 8542.0, EPS: 1.0
# Episode 7840:  Buffer size: 50000, Score: 7299.0, EPS: 1.0
# Episode 7860:  Buffer size: 50000, Score: 6976.0, EPS: 1.0
# Episode 7880:  Buffer size: 50000, Score: 5106.0, EPS: 1.0
# Episode 7900:  Buffer size: 50000, Score: 8432.0, EPS: 1.0
# Episode 7920:  Buffer size: 50000, Score: 7949.0, EPS: 1.0
# Episode 7940:  Buffer size: 50000, Score: 7583.0, EPS: 1.0
# Episode 7960:  Buffer size: 50000, Score: 5901.0, EPS: 1.0
# Episode 7980:  Buffer size: 50000, Score: 7010.0, EPS: 1.0
# Episode 8000:  Buffer size: 50000, Score: 7496.0, EPS: 1.0
# Episode 8020:  Buffer size: 50000, Score: 5375.0, EPS: 1.0
# Episode 8040:  Buffer size: 50000, Score: 4382.0, EPS: 1.0
# Episode 8060:  Buffer size: 50000, Score: 5907.0, EPS: 1.0
# Episode 8080:  Buffer size: 50000, Score: 4928.0, EPS: 1.0
# Episode 8100:  Buffer size: 50000, Score: 4064.0, EPS: 1.0
# Episode 8120:  Buffer size: 50000, Score: 3598.0, EPS: 1.0
# Episode 8140:  Buffer size: 50000, Score: 3204.0, EPS: 1.0
# Episode 8160:  Buffer size: 50000, Score: 2943.0, EPS: 1.0
# Episode 8180:  Buffer size: 50000, Score: 2781.0, EPS: 1.0
# Episode 8200:  Buffer size: 50000, Score: 2758.0, EPS: 1.0
# Episode 8220:  Buffer size: 50000, Score: 2892.0, EPS: 1.0
# Episode 8240:  Buffer size: 50000, Score: 3011.0, EPS: 1.0
# Episode 8260:  Buffer size: 50000, Score: 3457.0, EPS: 1.0
# Episode 8280:  Buffer size: 50000, Score: 3956.0, EPS: 1.0
# Episode 8300:  Buffer size: 50000, Score: 4810.0, EPS: 1.0
# Episode 8320:  Buffer size: 50000, Score: 5377.0, EPS: 1.0
# Episode 8340:  Buffer size: 50000, Score: 7128.0, EPS: 1.0
# Episode 8360:  Buffer size: 50000, Score: 8073.0, EPS: 1.0
# Episode 8380:  Buffer size: 50000, Score: 9666.0, EPS: 1.0
# Episode 8400:  Buffer size: 50000, Score: 8937.0, EPS: 1.0
# Episode 8420:  Buffer size: 50000, Score: 9304.0, EPS: 1.0
# Episode 8440:  Buffer size: 50000, Score: 9481.0, EPS: 1.0
# Episode 8460:  Buffer size: 50000, Score: 4731.0, EPS: 1.0
# Episode 8480:  Buffer size: 50000, Score: 5636.0, EPS: 1.0
# Episode 8500:  Buffer size: 50000, Score: 2242.0, EPS: 1.0
# Episode 8520:  Buffer size: 50000, Score: 3145.0, EPS: 1.0
# Episode 8540:  Buffer size: 50000, Score: 4226.0, EPS: 1.0
# Episode 8560:  Buffer size: 50000, Score: 6226.0, EPS: 1.0
# Episode 8580:  Buffer size: 50000, Score: 8657.0, EPS: 1.0
# Episode 8600:  Buffer size: 50000, Score: 9294.0, EPS: 1.0
# Episode 8620:  Buffer size: 50000, Score: 9638.0, EPS: 1.0
# Episode 8640:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 8660:  Buffer size: 50000, Score: 9850.0, EPS: 1.0
# Episode 8680:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 8700:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 8720:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 8740:  Buffer size: 50000, Score: 9249.0, EPS: 1.0
# Episode 8760:  Buffer size: 50000, Score: 9188.0, EPS: 1.0
# Episode 8780:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 8800:  Buffer size: 50000, Score: 9661.0, EPS: 1.0
# Episode 8820:  Buffer size: 50000, Score: 9410.0, EPS: 1.0
# Episode 8840:  Buffer size: 50000, Score: 9300.0, EPS: 1.0
# Episode 8860:  Buffer size: 50000, Score: 9328.0, EPS: 1.0
# Episode 8880:  Buffer size: 50000, Score: 8997.0, EPS: 1.0
# Episode 8900:  Buffer size: 50000, Score: 8684.0, EPS: 1.0
# Episode 8920:  Buffer size: 50000, Score: 10000.0, EPS: 1.0
# Episode 8940:  Buffer size: 50000, Score: 8940.0, EPS: 1.0
# Episode 8960:  Buffer size: 50000, Score: 6910.0, EPS: 1.0
# Episode 8980:  Buffer size: 50000, Score: 4965.0, EPS: 1.0
# Episode 9000:  Buffer size: 50000, Score: 5107.0, EPS: 1.0
# Episode 9020:  Buffer size: 50000, Score: 4538.0, EPS: 1.0
# Episode 9040:  Buffer size: 50000, Score: 4067.0, EPS: 1.0
# Episode 9060:  Buffer size: 50000, Score: 3813.0, EPS: 1.0
# Episode 9080:  Buffer size: 50000, Score: 4242.0, EPS: 1.0
# Episode 9100:  Buffer size: 50000, Score: 4017.0, EPS: 1.0
# Episode 9120:  Buffer size: 50000, Score: 3690.0, EPS: 1.0
# Episode 9140:  Buffer size: 50000, Score: 2777.0, EPS: 1.0
# Episode 9160:  Buffer size: 50000, Score: 3955.0, EPS: 1.0
# Episode 9180:  Buffer size: 50000, Score: 8235.0, EPS: 1.0
# Episode 9200:  Buffer size: 50000, Score: 8431.0, EPS: 1.0
# Episode 9220:  Buffer size: 50000, Score: 7640.0, EPS: 1.0
# Episode 9240:  Buffer size: 50000, Score: 6194.0, EPS: 1.0
# Episode 9260:  Buffer size: 50000, Score: 8100.0, EPS: 1.0
# Episode 9280:  Buffer size: 50000, Score: 4941.0, EPS: 1.0
# Episode 9300:  Buffer size: 50000, Score: 8141.0, EPS: 1.0
# Episode 9320:  Buffer size: 50000, Score: 9077.0, EPS: 1.0
# Episode 9340:  Buffer size: 50000, Score: 9672.0, EPS: 1.0
# Episode 9360:  Buffer size: 50000, Score: 8755.0, EPS: 1.0
# Episode 9380:  Buffer size: 50000, Score: 9170.0, EPS: 1.0
# Episode 9400:  Buffer size: 50000, Score: 8959.0, EPS: 1.0
# Episode 9420:  Buffer size: 50000, Score: 9570.0, EPS: 1.0
# Episode 9440:  Buffer size: 50000, Score: 9701.0, EPS: 1.0
# Episode 9460:  Buffer size: 50000, Score: 9920.0, EPS: 1.0
# Episode 9480:  Buffer size: 50000, Score: 9408.0, EPS: 1.0
# Episode 9500:  Buffer size: 50000, Score: 7923.0, EPS: 1.0
# Episode 9520:  Buffer size: 50000, Score: 8976.0, EPS: 1.0
# Episode 9540:  Buffer size: 50000, Score: 9655.0, EPS: 1.0
# Episode 9560:  Buffer size: 50000, Score: 9688.0, EPS: 1.0
# Episode 9580:  Buffer size: 50000, Score: 8408.0, EPS: 1.0
# Episode 9600:  Buffer size: 50000, Score: 6711.0, EPS: 1.0
# Episode 9620:  Buffer size: 50000, Score: 8469.0, EPS: 1.0
# Episode 9640:  Buffer size: 50000, Score: 8566.0, EPS: 1.0
# Episode 9660:  Buffer size: 50000, Score: 9168.0, EPS: 1.0
# Episode 9680:  Buffer size: 50000, Score: 9599.0, EPS: 1.0
# Episode 9700:  Buffer size: 50000, Score: 9513.0, EPS: 1.0
# Episode 9720:  Buffer size: 50000, Score: 8440.0, EPS: 1.0
# Episode 9740:  Buffer size: 50000, Score: 7108.0, EPS: 1.0
# Episode 9760:  Buffer size: 50000, Score: 7906.0, EPS: 1.0
# Episode 9780:  Buffer size: 50000, Score: 6727.0, EPS: 1.0
# Episode 9800:  Buffer size: 50000, Score: 1324.0, EPS: 1.0
# Episode 9820:  Buffer size: 50000, Score: 2258.0, EPS: 1.0
# Episode 9840:  Buffer size: 50000, Score: 1401.0, EPS: 1.0
# Episode 9860:  Buffer size: 50000, Score: 7631.0, EPS: 1.0
# Episode 9880:  Buffer size: 50000, Score: 8297.0, EPS: 1.0
# Episode 9900:  Buffer size: 50000, Score: 8148.0, EPS: 1.0
# Episode 9920:  Buffer size: 50000, Score: 7971.0, EPS: 1.0
# Episode 9940:  Buffer size: 50000, Score: 9440.0, EPS: 1.0
# Episode 9960:  Buffer size: 50000, Score: 8243.0, EPS: 1.0
# Episode 9980:  Buffer size: 50000, Score: 7375.0, EPS: 1.0

# %% [markdown]
# We see that the learning is improving from one episode to other one, but it is not stable which was expected, as the problem is probabilistic. But, in general the algorithm is doing well for this game and by chosing a complex models we may have a better results
